# %% [markdown]
# <a href="https://colab.research.google.com/github/Gayatri925/AI-Powered-Workforce-Analytics-Talent-Intelligence-Dashboard/blob/main/PythonTasks.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# **Python Tasks**

# %%
import pandas as pd

# %% [markdown]
# **Prompt:** This program uses the Pandas library to create a sample HR employee dataset containing 20 employee records. Each record includes the Employee ID, Age, Department, Total Working Years, and Performance Rating. The dataset is converted into a Pandas DataFrame for easy manipulation and analysis. Finally, the DataFrame is displayed on the screen and saved as a CSV file for future use in HR Analytics and Machine Learning applications.

# %%
import pandas as pd

data = [
    {"Employee_ID": "EMP001", "Age": 24, "Department": "IT", "Total_Working_Years": 2, "Performance_Rating": 3},
    {"Employee_ID": "EMP002", "Age": 28, "Department": "HR", "Total_Working_Years": 5, "Performance_Rating": 4},
    {"Employee_ID": "EMP003", "Age": 35, "Department": "Finance", "Total_Working_Years": 10, "Performance_Rating": 5},
    {"Employee_ID": "EMP004", "Age": 30, "Department": "Sales", "Total_Working_Years": 7, "Performance_Rating": 4},
    {"Employee_ID": "EMP005", "Age": 26, "Department": "Marketing", "Total_Working_Years": 4, "Performance_Rating": 3},
    {"Employee_ID": "EMP006", "Age": 41, "Department": "IT", "Total_Working_Years": 18, "Performance_Rating": 5},
    {"Employee_ID": "EMP007", "Age": 33, "Department": "HR", "Total_Working_Years": 9, "Performance_Rating": 4},
    {"Employee_ID": "EMP008", "Age": 29, "Department": "Finance", "Total_Working_Years": 6, "Performance_Rating": 3},
    {"Employee_ID": "EMP009", "Age": 45, "Department": "Operations", "Total_Working_Years": 22, "Performance_Rating": 5},
    {"Employee_ID": "EMP010", "Age": 31, "Department": "Sales", "Total_Working_Years": 8, "Performance_Rating": 4},
    {"Employee_ID": "EMP011", "Age": 27, "Department": "Marketing", "Total_Working_Years": 5, "Performance_Rating": 3},
    {"Employee_ID": "EMP012", "Age": 39, "Department": "IT", "Total_Working_Years": 15, "Performance_Rating": 5},
    {"Employee_ID": "EMP013", "Age": 36, "Department": "Finance", "Total_Working_Years": 12, "Performance_Rating": 4},
    {"Employee_ID": "EMP014", "Age": 25, "Department": "HR", "Total_Working_Years": 3, "Performance_Rating": 3},
    {"Employee_ID": "EMP015", "Age": 42, "Department": "Operations", "Total_Working_Years": 20, "Performance_Rating": 5},
    {"Employee_ID": "EMP016", "Age": 34, "Department": "Sales", "Total_Working_Years": 11, "Performance_Rating": 4},
    {"Employee_ID": "EMP017", "Age": 38, "Department": "Marketing", "Total_Working_Years": 14, "Performance_Rating": 5},
    {"Employee_ID": "EMP018", "Age": 23, "Department": "IT", "Total_Working_Years": 1, "Performance_Rating": 2},
    {"Employee_ID": "EMP019", "Age": 32, "Department": "Finance", "Total_Working_Years": 9, "Performance_Rating": 4},
    {"Employee_ID": "EMP020", "Age": 40, "Department": "Operations", "Total_Working_Years": 17, "Performance_Rating": 5}
]

df = pd.DataFrame(data)
print(df)

# Save the dataset to a CSV file
df.to_csv("employee_dataset.csv", index=False)

print("Dataset saved successfully!")
# Out:
#    Employee_ID  Age  Department  Total_Working_Years  Performance_Rating
# 0       EMP001   24          IT                    2                   3
# 1       EMP002   28          HR                    5                   4
# 2       EMP003   35     Finance                   10                   5
# 3       EMP004   30       Sales                    7                   4
# 4       EMP005   26   Marketing                    4                   3
# 5       EMP006   41          IT                   18                   5
# 6       EMP007   33          HR                    9                   4
# 7       EMP008   29     Finance                    6                   3
# 8       EMP009   45  Operations                   22                   5
# 9       EMP010   31       Sales                    8                   4
# 10      EMP011   27   Marketing                    5                   3
# 11      EMP012   39          IT                   15                   5
# ...

# %% [markdown]
# **Prompt:** to perform basic data exploration on the employee dataset by displaying the first and last five records, dataset dimensions, dataset information, column names, and data types using Pandas.

# %%
print(df.head())
# Out:
#   Employee_ID  Age Department  Total_Working_Years  Performance_Rating
# 0      EMP001   24         IT                    2                   3
# 1      EMP002   28         HR                    5                   4
# 2      EMP003   35    Finance                   10                   5
# 3      EMP004   30      Sales                    7                   4
# 4      EMP005   26  Marketing                    4                   3

# %%
print(df.tail())
# Out:
#    Employee_ID  Age  Department  Total_Working_Years  Performance_Rating
# 15      EMP016   34       Sales                   11                   4
# 16      EMP017   38   Marketing                   14                   5
# 17      EMP018   23          IT                    1                   2
# 18      EMP019   32     Finance                    9                   4
# 19      EMP020   40  Operations                   17                   5

# %%
print(df.shape)
# Out:
# (20, 5)

# %%
print(df.info())
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 20 entries, 0 to 19
# Data columns (total 5 columns):
#  #   Column               Non-Null Count  Dtype
# ---  ------               --------------  -----
#  0   Employee_ID          20 non-null     object
#  1   Age                  20 non-null     int64
#  2   Department           20 non-null     object
#  3   Total_Working_Years  20 non-null     int64
#  4   Performance_Rating   20 non-null     int64
# dtypes: int64(3), object(2)
# memory usage: 932.0+ bytes
# None

# %%
print(df.columns)
# Out:
# Index(['Employee_ID', 'Age', 'Department', 'Total_Working_Years',
#        'Performance_Rating'],
#       dtype='object')

# %%
print(df.dtypes)
# Out:
# Employee_ID            object
# Age                     int64
# Department             object
# Total_Working_Years     int64
# Performance_Rating      int64
# dtype: object

# %% [markdown]
# **Prompt:** to perform list operations on the Employee_ID column by converting it into a list and displaying all employee IDs, the first five employee IDs, and the last five employee IDs.

# %%
employee_list = df["Employee_ID"].tolist()

print(employee_list)
# Out:
# ['EMP001', 'EMP002', 'EMP003', 'EMP004', 'EMP005', 'EMP006', 'EMP007', 'EMP008', 'EMP009', 'EMP010', 'EMP011', 'EMP012', 'EMP013', 'EMP014', 'EMP015', 'EMP016', 'EMP017', 'EMP018', 'EMP019', 'EMP020']

# %%
print(employee_list[:5])
print(employee_list[-5:])
# Out:
# ['EMP001', 'EMP002', 'EMP003', 'EMP004', 'EMP005']
# ['EMP016', 'EMP017', 'EMP018', 'EMP019', 'EMP020']

# %% [markdown]
# **Prompt:** to perform a Tuple operation by converting the Department column of the employee dataset into a tuple and displaying its elements.

# %%
department_tuple = tuple(df["Department"])

print(department_tuple)
# Out:
# ('IT', 'HR', 'Finance', 'Sales', 'Marketing', 'IT', 'HR', 'Finance', 'Operations', 'Sales', 'Marketing', 'IT', 'Finance', 'HR', 'Operations', 'Sales', 'Marketing', 'IT', 'Finance', 'Operations')

# %% [markdown]
# **Prompt:** to perform a Dictionary operation by converting the first employee record of the dataset into a dictionary using the to_dict() method and displaying the key-value pairs.

# %%
employee_dict = df.iloc[0].to_dict()

print(employee_dict)
# Out:
# {'Employee_ID': 'EMP001', 'Age': 24, 'Department': 'IT', 'Total_Working_Years': 2, 'Performance_Rating': 3}

# %% [markdown]
# **Prompt:** to perform a Set operation by converting the Department column of the employee dataset into a set to display the unique department names.

# %%
department_set = set(df["Department"])

print(department_set)
# Out:
# {'Sales', 'Finance', 'Marketing', 'HR', 'Operations', 'IT'}

# %% [markdown]
# **Prompt:** to perform a For Loop operation by iterating through the Employee_ID column of the employee dataset and displaying each employee ID.

# %%
for emp in df["Employee_ID"]:
    print(emp)
# Out:
# EMP001
# EMP002
# EMP003
# EMP004
# EMP005
# EMP006
# EMP007
# EMP008
# EMP009
# EMP010
# EMP011
# EMP012
# EMP013
# EMP014
# EMP015
# EMP016
# EMP017
# EMP018
# EMP019
# EMP020

# %% [markdown]
# **Prompt:** to perform a Lambda Function operation by defining a lambda function to double the employee's total working years and display the result.

# %%
double_experience = lambda x: x * 2

print(double_experience(5))
# Out:
# 10
